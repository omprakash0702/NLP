# %% [markdown]
# # Assignment 2: Naive Bayes
# Welcome to week two of this specialization. You will learn about Naive Bayes. Concretely, you will be using Naive Bayes for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Train a naive bayes model on a sentiment analysis task
# * Test using your model
# * Compute ratios of positive words to negative words
# * Do some error analysis
# * Predict on your own tweet
#
# You may already be familiar with Naive Bayes and its justification in terms of conditional probabilities and independence.
# * In this week's lectures and assignments we used the ratio of probabilities between positive and negative sentiment.
# * This approach gives us simpler formulas for these 2-way classification tasks.
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader Error: Grader feedback not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/classification-vector-spaces-in-nlp/supplement/YLuAg/h-ow-to-refresh-your-workspace).
#
# Lets get started!
#
# Load the cell below to import some packages.
# You  may want to browse the documentation of unfamiliar libraries and functions.

# %% [markdown]
# ## Table of Contents
#
# - [Importing Functions and Data](#0)
# - [1 - Process the Data](#1)
#     - [1.1 - Implementing your Helper Functions](#1-1)
#         - [Exercise 1 - count_tweets (UNQ_C1)](#ex-1)
# - [2 - Train your Model using Naive Bayes](#2)
#     - [Exercise 2 - train_naive_bayes (UNQ_C2)](#ex-2)
# - [3 - Test your Naive Bayes](#3)
#     - [Exercise 3 - naive_bayes_predict  (UNQ_C4)](#ex-3)
#     - [Exercise 4 - test_naive_bayes (UNQ_C6)](#ex-4)
# - [4 - Filter words by Ratio of Positive to Negative Counts](#4)
#     - [Exercise 5 - get_ratio (UNQ_C8)](#ex-5)
#     - [Exercise 6 - get_words_by_threshold (UNQ_C9)](#ex-6)
# - [5 - Error Analysis](#5)
# - [6 - Predict with your own Tweet](#6)

# %% [markdown]
# <a name='0'></a>
# ## Importing Functions and Data

# %%
from utils import process_tweet, lookup
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd
import w2_unittest

nltk.download('twitter_samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# If you are running this notebook in your local computer,
# don't forget to download the tweeter samples and stopwords from nltk.
#
# ```
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# ```

# %%
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
# get the sets of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# <a name='1'></a>
# ## 1 - Process the Data
#
# For any machine learning project, once you've gathered the data, the first step is to process it to make useful inputs to your model.
# - **Remove noise**: You will first want to remove noise from your data -- that is, remove words that don't tell you much about the content. These include all common words like 'I, you, are, is, etc...' that would not give us enough information on the sentiment.
# - We'll also remove stock market tickers, retweet symbols, hyperlinks, and hashtags because they can not tell you a lot of information on the sentiment.
# - You also want to remove all the punctuation from a tweet. The reason for doing this is because we want to treat words with or without the punctuation as the same word, instead of treating "happy", "happy?", "happy!", "happy," and "happy." as different words.
# - Finally you want to use stemming to only keep track of one variation of each word. In other words, we'll treat "motivation", "motivated", and "motivate" similarly by grouping them within the same stem of "motiv-".
#
# We have given you the function `process_tweet` that does this for you.

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"

# print cleaned tweet
print(process_tweet(custom_tweet))
# Out:
# ['hello', 'great', 'day', ':)', 'good', 'morn']

# %% [markdown]
# <a name='1-1'></a>
# ### 1.1 - Implementing your Helper Functions
#
# To help you train your naive bayes model, you will need to compute a dictionary where the keys are a tuple (word, label) and the values are the corresponding frequency.  Note that the labels we'll use here are 1 for positive and 0 for negative.
#
# You will also implement a lookup helper function that takes in the `freqs` dictionary, a word, and a label (1 or 0) and returns the number of times that word and label tuple appears in the collection of tweets.
#
# For example: given a list of tweets `["i am rather excited", "you are rather happy"]` and the label 1, the function will return a dictionary that contains the following key-value pairs:
#
# {
#     ("rather", 1): 2,
#     ("happi", 1) : 1,
#     ("excit", 1) : 1
# }
#
# - Notice how for each word in the given string, the same label 1 is assigned to each word.
# - Notice how the words "i" and "am" are not saved, since it was removed by process_tweet because it is a stopword.
# - Notice how the word "rather" appears twice in the list of tweets, and so its count value is 2.
#
# <a name='ex-1'></a>
# ### Exercise 1 - count_tweets
# Create a function `count_tweets` that takes a list of tweets as input, cleans all of them, and returns a dictionary.
# - The key in the dictionary is a tuple containing the stemmed word and its class label, e.g. ("happi",1).
# - The value the number of times this word appears in the given collection of tweets (an integer).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Please use the `process_tweet` function that was imported above, and then store the words in their respective dictionaries and sets.</li>
#     <li>You may find it useful to use the `zip` function to match each element in `tweets` with each element in `ys`.</li>
#     <li>Remember to check if the key in the dictionary exists before adding that key to the dictionary, or incrementing its value.</li>
#     <li>Assume that the `result` dictionary that is input will contain clean key-value pairs (you can assume that the values will be integers that can be incremented).  It is good practice to check the datatype before incrementing the value, but it's not required here.</li>
# </ul>
# </p>

# %%
def count_tweets(result, tweets, ys):
    '''
    Input:
        result: a dictionary that will be used to map each pair to its frequency
        tweets: a list of tweets
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            pair = (word, y)
            if pair in result:
                result[pair] += 1
            else:
                result[pair] = 1
    return result

# %%
# Testing your function

result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# **Expected Output**: {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %%
# Test your function
w2_unittest.test_count_tweets(count_tweets)
# Out:
#  All tests passed

# %% [markdown]
# <a name='2'></a>
# ## 2 - Train your Model using Naive Bayes
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# #### So how do you train a Naive Bayes classifier?
# - The first part of training a naive bayes classifier is to identify the number of classes that you have.
# - You will create a probability for each class.
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Where $D$ is the total number of documents, or tweets in this case, $D_{pos}$ is the total number of positive tweets and $D_{neg}$ is the total number of negative tweets.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a tweet is positive versus negative.  In other words, if we had no specific information and blindly picked a tweet out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note that $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So the logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all documents (for all tweets), respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Notice that we add the "+1" in the numerator for additive smoothing.  This [wiki article](https://en.wikipedia.org/wiki/Additive_smoothing) explains more about additive smoothing.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Create `freqs` dictionary
# - Given your `count_tweets` function, you can compute a dictionary called `freqs` that contains all the frequencies.
# - In this `freqs` dictionary, the key is the tuple (word, label)
# - The value is the number of times it has appeared.
#
# We will use this dictionary in several parts of this assignment.

# %%
# Build the freqs dictionary for later uses
freqs = count_tweets({}, train_x, train_y)

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - train_naive_bayes
# Given a freqs dictionary, `train_x` (a list of tweets) and a `train_y` (a list of labels for each tweet), implement a naive bayes classifier.
#
# ##### Calculate $V$
# - You can then compute the number of unique words that appear in the `freqs` dictionary to get your $V$ (you can use the `set` function).
#
# ##### Calculate $freq_{pos}$ and $freq_{neg}$
# - Using your `freqs` dictionary, you can compute the positive and negative frequency of each word $freq_{pos}$ and $freq_{neg}$.
#
# ##### Calculate $N_{pos}$, and $N_{neg}$
# - Using `freqs` dictionary, you can also compute the total number of positive words and total number of negative words $N_{pos}$ and $N_{neg}$.
#
# ##### Calculate $D$, $D_{pos}$, $D_{neg}$
# - Using the `train_y` input list of labels, calculate the number of documents (tweets) $D$, as well as the number of positive documents (tweets) $D_{pos}$ and number of negative documents (tweets) $D_{neg}$.
# - Calculate the probability that a document (tweet) is positive $P(D_{pos})$, and the probability that a document (tweet) is negative $P(D_{neg})$
#
# ##### Calculate the logprior
# - the logprior is $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finally, you can iterate over each word in the vocabulary, use your `lookup` function to get the positive frequencies, $freq_{pos}$, and the negative frequencies, $freq_{neg}$, for that specific word.
# - Compute the positive probability of each word $P(W_{pos})$, negative probability of each word $P(W_{neg})$ using equations 4 & 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** We'll use a dictionary to store the log likelihoods for each word.  The key is the word, the value is the log likelihood of that word).
#
# - You can then compute the loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)$.

# %%
def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of tweets
        train_y: a list of labels corresponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0

    # Calculate the number of unique words in the vocabulary
    vocab = set([word for word, _ in freqs.keys()])
    V = len(vocab)

    # Calculate N_pos, N_neg
    N_pos = sum([count for (word, label), count in freqs.items() if label == 1])
    N_neg = sum([count for (word, label), count in freqs.items() if label == 0])

    # Calculate D, D_pos, D_neg
    D = len(train_y)
    D_pos = sum(1 for label in train_y if label == 1)
    D_neg = D - D_pos

    # Calculate logprior
    logprior = np.log(D_pos / D_neg)

    # Calculate loglikelihood
    for word in vocab:
        freq_pos = lookup(freqs, word, 1)
        freq_neg = lookup(freqs, word, 0)
        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)
        loglikelihood[word] = np.log(p_w_pos / p_w_neg)

    return logprior, loglikelihood

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# 0.0
# 9165

# %% [markdown]
# **Expected Output**:
#
# 0.0
#
# 9165

# %%
# Test your function
w2_unittest.test_train_naive_bayes(train_naive_bayes, freqs, train_x, train_y)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3'></a>
# ## 3 - Test your Naive Bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predicting on some tweets!
#
# <a name='ex-3'></a>
# ### Exercise 3 - naive_bayes_predict
# Implement `naive_bayes_predict`.
#
# **Instructions**:
# Implement the `naive_bayes_predict` function to make predictions on tweets.
# * The function takes in the `tweet`, `logprior`, `loglikelihood`.
# * It returns the probability that the tweet belongs to the positive or negative class.
# * For each tweet, sum up loglikelihoods of each word in the tweet.
# * Also add the logprior to this sum to get the predicted sentiment of that tweet.
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (4000 positive and 4000 negative tweets).  This means that the ratio of positive to negative 1, and the logprior is 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, please remember to include the logprior, because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    Input:
        tweet: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)
    '''
    word_l = process_tweet(tweet)
    p = logprior

    for word in word_l:
        if word in loglikelihood:
            p += loglikelihood[word]

    return p

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
my_tweet = 'She smiled.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 1.5577981920239676

# %% [markdown]
# **Expected Output**:
# - The expected output is around 1.55
# - The sentiment is positive.

# %%
# Test your function
w2_unittest.test_naive_bayes_predict(naive_bayes_predict)
# Out:
#  All tests passed

# %%
# Experiment with your own tweet.
my_tweet = 'He laughed.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is -0.1649684057171359

# %% [markdown]
# <a name='ex-4'></a>
# ### Exercise 4 - test_naive_bayes
# Implement test_naive_bayes.
#
# **Instructions**:
# * Implement `test_naive_bayes` to check the accuracy of your predictions.
# * The function takes in your `test_x`, `test_y`, log_prior, and loglikelihood
# * It returns the accuracy of your model.
# * First, use `naive_bayes_predict` function to make predictions for each tweet in text_x.

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood, naive_bayes_predict=naive_bayes_predict):
    """
    Input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of tweets classified correctly)/(total # of tweets)
    """
    correct_predictions = 0

    for tweet, true_label in zip(test_x, test_y):
        predicted_prob = naive_bayes_predict(tweet, logprior, loglikelihood)
        predicted_label = 1 if predicted_prob > 0 else 0
        if predicted_label == true_label:
            correct_predictions += 1

    accuracy = correct_predictions / len(test_y)
    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 0.9955

# %% [markdown]
# **Expected Accuracy**:
#
# `Naive Bayes accuracy = 0.9955`

# %%
# UNQ_C7 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    # print( '%s -> %f' % (tweet, naive_bayes_predict(tweet, logprior, loglikelihood)))
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
#     print(f'{tweet} -> {p:.2f} ({p_category})')
    print(f'{tweet} -> {p:.2f}')
# Out:
# I am happy -> 2.14
# I am bad -> -1.31
# this movie should have been great. -> 2.12
# great -> 2.13
# great great -> 4.26
# great great great -> 6.39
# great great great great -> 8.52

# %% [markdown]
# **Expected Output**:
# - I am happy -> 2.14
# - I am bad -> -1.31
# - this movie should have been great. -> 2.12
# - great -> 2.13
# - great great -> 4.26
# - great great great -> 6.39
# - great great great great -> 8.52

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'you are bad :('
naive_bayes_predict(my_tweet, logprior, loglikelihood)
# Out:
# -8.837351738825648

# %%
# Test your function
w2_unittest.unittest_test_naive_bayes(test_naive_bayes, test_x, test_y)
# Out:
#  All tests passed

# %% [markdown]
# <a name='4'></a>
# ## 4 - Filter words by Ratio of Positive to Negative Counts
#
# - Some words have more positive counts than others, and can be considered "more positive".  Likewise, some words can be considered more negative than others.
# - One way for us to define the level of positiveness or negativeness, without calculating the log likelihood, is to compare the positive to negative frequency of the word.
#     - Note that we can also use the log likelihood calculations to compare relative positivity or negativity of words.
# - We can calculate the ratio of positive to negative frequencies of a word.
# - Once we're able to calculate these ratios, we can also filter a subset of words that have a minimum ratio of positivity / negativity or higher.
# - Similarly, we can also filter a subset of words that have a maximum ratio of positivity / negativity or lower (words that are at least as negative, or even more negative than a given threshold).
#
# <a name='ex-5'></a>
# ### Exercise 5 - get_ratio
# Implement get_ratio.
#
# - Given the freqs dictionary of words and a particular word, use `lookup(freqs,word,1)` to get the positive count of the word.
# - Similarly, use the `lookup` function to get the negative count of that word.
# - Calculate the ratio of positive divided by negative counts
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words
    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}
    pos_neg_ratio['positive'] = lookup(freqs, word, 1)
    pos_neg_ratio['negative'] = lookup(freqs, word, 0)

    if pos_neg_ratio['negative'] == 0:
        pos_neg_ratio['ratio'] = float('inf')  # Avoid division by zero
    else:
        pos_neg_ratio['ratio'] = (pos_neg_ratio['positive'] + 1) / (pos_neg_ratio['negative'] + 1)
    
    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positive': 162, 'negative': 18, 'ratio': 8.578947368421053}

# %%
# Test your function
w2_unittest.test_get_ratio(get_ratio, freqs)
# Out:
#  All tests passed

# %% [markdown]
# <a name='ex-6'></a>
# ### Exercise 6 - get_words_by_threshold
# Implement get_words_by_threshold(freqs,label,threshold)
#
# * If we set the label to 1, then we'll look for all words whose threshold of positive/negative is at least as high as that threshold, or higher.
# * If we set the label to 0, then we'll look for all words whose threshold of positive/negative is at most as low as the given threshold, or lower.
# * Use the `get_ratio` function to get a dictionary containing the positive count, negative count, and the ratio of positive to negative counts.
# * Append the `get_ratio` dictionary inside another dictinoary, where the key is the word, and the value is the dictionary `pos_neg_ratio` that is returned by the `get_ratio` function.
# An example key-value pair would have this structure:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.524}
# }
# ```

# %%
def get_words_by_threshold(freqs, label, threshold, get_ratio=get_ratio):
    '''
    Input:
        freqs: dictionary of words
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_list: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}

    for word in freqs.keys():
        _, current_label = word
        pos_neg_ratio = get_ratio(freqs, word[0])

        if label == 1 and pos_neg_ratio['ratio'] >= threshold:
            word_list[word[0]] = pos_neg_ratio
        elif label == 0 and pos_neg_ratio['ratio'] <= threshold:
            word_list[word[0]] = pos_neg_ratio

    return word_list

# %%
# Test your function: find negative words at or below a threshold
get_words_by_threshold(freqs, label=0, threshold=0.05)
# Out:
# {':(': {'positive': 1, 'negative': 3675, 'ratio': 0.000544069640914037},
#  ':-(': {'positive': 0, 'negative': 386, 'ratio': 0.002583979328165375},
#  'zayniscomingbackonjuli': {'positive': 0, 'negative': 19, 'ratio': 0.05},
#  '26': {'positive': 0, 'negative': 20, 'ratio': 0.047619047619047616},
#  '>:(': {'positive': 0, 'negative': 43, 'ratio': 0.022727272727272728},
#  'lost': {'positive': 0, 'negative': 19, 'ratio': 0.05},
#  '♛': {'positive': 0, 'negative': 210, 'ratio': 0.004739336492890996},
#  '》': {'positive': 0, 'negative': 210, 'ratio': 0.004739336492890996},
#  'beli̇ev': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'wi̇ll': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'justi̇n': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'ｓｅｅ': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'ｍｅ': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776}}

# %%
# Test your function; find positive words at or above a threshold
get_words_by_threshold(freqs, label=1, threshold=10)
# Out:
# {'followfriday': {'positive': 23, 'negative': 0, 'ratio': inf},
#  'engag': {'positive': 7, 'negative': 0, 'ratio': inf},
#  'commun': {'positive': 27, 'negative': 1, 'ratio': 14.0},
#  ':)': {'positive': 2960, 'negative': 2, 'ratio': 987.0},
#  '02392441234': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'assist': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yeaaah': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yipppi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'accnt': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'verifi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'rqst': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'succeed': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tick': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'irresist': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'flipkartfashionfriday': {'positive': 16, 'negative': 0, 'ratio': inf},
#  'lwwf': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bayan': {'positive': 1, 'negative': 0, 'ratio': inf},
#  ':D': {'positive': 523, 'negative': 0, 'ratio': inf},
#  'mischiev': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'etl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'layer': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'in-hous': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wareh': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'katamari': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'impli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  ':p': {'positive': 104, 'negative': 0, 'ratio': inf},
#  'influenc': {'positive': 16, 'negative': 0, 'ratio': inf},
#  'juici': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'junior': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'triathlet': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gatorad': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'print': {'positive': 4, 'negative': 0, 'ratio': inf},
#  ':-)': {'positive': 552, 'negative': 0, 'ratio': inf},
#  "friend'": {'positive': 3, 'negative': 0, 'ratio': inf},
#  'yummm': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'nostalgia': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tb': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ku': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'conflict': {'positive': 1, 'negative': 0, 'ratio': inf},
#  "here'": {'positive': 20, 'negative': 0, 'ratio': inf},
#  'liv': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'fm': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'dope': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'penthous': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'obv': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gobigorgohom': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'youth': {'positive': 14, 'negative': 0, 'ratio': inf},
#  '💅': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'spiritu': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ritual': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'népal': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'line-up': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'sarah': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'bitsy@bitdefender.com': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hatessuc': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '32429': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cumshot': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'nsn_supplement': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'press': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'distribut': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pressreleas': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'newsdistribut': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bam': {'positive': 44, 'negative': 0, 'ratio': inf},
#  'warsaw': {'positive': 44, 'negative': 0, 'ratio': inf},
#  'x46': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'documentari': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'earthl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'letsgetmessi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'soundtrack': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'shout': {'positive': 11, 'negative': 0, 'ratio': inf},
#  'twitch': {'positive': 7, 'negative': 0, 'ratio': inf},
#  'gameplay': {'positive': 1, 'negative': 0, 'ratio': inf},
#  ';)': {'positive': 22, 'negative': 0, 'ratio': inf},
#  'etsi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'boxroomcraft': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'recharg': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'speech': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'canal': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dasvidaniya': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'scout': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wlan': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pro': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'lollipop': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '🍭': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'nez': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'agnezmo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'oley': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'stronger': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'misti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'woohoo': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'mka': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'stat': {'positive': 51, 'negative': 0, 'ratio': inf},
#  'arriv': {'positive': 57, 'negative': 4, 'ratio': 11.6},
#  'happybirthdayemilybett': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'timezon': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'manila_bro': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'chosen': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'x45': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hushedcallwithfraydo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hushedpinwithsammi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'scope': {'positive': 5, 'negative': 0, 'ratio': inf},
#  't-shirt': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'haw': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'phela': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'princ': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tyler': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hipster': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'marti': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'glad': {'positive': 41, 'negative': 2, 'ratio': 14.0},
#  'kahfi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ohmyg': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yaya': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'dub': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ig': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'gondooo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'moo': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'tologooo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'physiotherapi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'x43': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'advic': {'positive': 6, 'negative': 0, 'ratio': inf},
#  'treviso': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'oven': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'roast': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'garlic': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'oliv': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'centuri': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tuna': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'atchya': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'heheheh': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'volta': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'funcionar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jailbroken': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '34': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'leia': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hologram': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'r2d2': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'obi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ucl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'arsen': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '🚂': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dewsburi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'dew': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yorkshir': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '430': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '9:25': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'strang': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'masaantoday': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'a4': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'shweta': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tripathi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'kurta': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'larri': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'enn': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'warmup': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '15th': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'bath': {'positive': 6, 'negative': 0, 'ratio': inf},
#  'dum': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'andar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ram': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sampath': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sona': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mohapatra': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'samantha': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tulan': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'razi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '16.20': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'giveitup': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ga': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'subsidi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'x42': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'lmaoo': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'throwback': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'outli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cheung': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'chau': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mui': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'kfckitchentour': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'cusp': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'reward': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'arummzz': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'yogyakarta': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'jeep': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'instamood': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'pretend': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'winner': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'cheesydelight': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'contest': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'wd': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'engin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'blog': {'positive': 27, 'negative': 0, 'ratio': inf},
#  '☆': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'triangl': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'northern': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'smthng': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'xoxo': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'jaann': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'topnewfollow': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'pirouett': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'moos': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'philli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'x41': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'flaw': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'negat': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fav': {'positive': 11, 'negative': 0, 'ratio': inf},
#  'nirvana': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'winehous': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tomhiddleston': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'elizabetholsen': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yaytheylookgreat': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'vid': {'positive': 8, 'negative': 0, 'ratio': inf},
#  'itti': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'bitti': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'teeni': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'bikini': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'xfile': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fabul': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'fantast': {'positive': 9, 'negative': 0, 'ratio': inf},
#  'jb': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'nighti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'foundri': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sens': {'positive': 6, 'negative': 0, 'ratio': inf},
#  'ef': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'woot': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'parkshar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gloucestershir': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'aaaahhh': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'reliev': {'positive': 1, 'negative': 0, 'ratio': inf},
#  "how'r": {'positive': 1, 'negative': 0, 'ratio': inf},
#  'arbeloa': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '17': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'uncount': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'unlimit': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'teamposit': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'rita': {'positive': 2, 'negative': 0, 'ratio': inf},
#  "we'd": {'positive': 4, 'negative': 0, 'ratio': inf},
#  'x40': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sethi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'exe': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'skeem': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'saam': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'izzat': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wese': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'khawateen': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sath': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'kar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'deya': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tee': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'mclaren': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'squar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'enix': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bissmillah': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'socent': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'startup': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'arnd': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'complic': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sport': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'rakyat': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ourdaughtersourprid': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'mypapamyprid': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'papa': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'kha': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'atleast': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'x39': {'positive': 1, 'negative': 0, 'ratio': inf},
#  "lassi'": {'positive': 1, 'negative': 0, 'ratio': inf},
#  "monty'": {'positive': 1, 'negative': 0, 'ratio': inf},
#  'suspect': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'kepler': {'positive': 3, 'negative': 0, 'ratio': inf},
#  '452b': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'chalna': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hazel': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pta': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'okayi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'doc': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'splendid': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'amount': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'nigeria': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'thaaank': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'puhon': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'happinesss': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tnc': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'prior': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '2:22': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yuna': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'tamesid': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'scouser': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'zoe': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'samee': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'edgar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'abe': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'x38': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dreamili': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pout': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'quacketyquack': {'positive': 6, 'negative': 0, 'ratio': inf},
#  'phil': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'del': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'rodder': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'newest': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gamejam': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'irish': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'literatur': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'inaccess': {'positive': 2, 'negative': 0, 'ratio': inf},
#  "kareena'": {'positive': 2, 'negative': 0, 'ratio': inf},
#  'braindot': {'positive': 8, 'negative': 0, 'ratio': inf},
#  'brandi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'carniv': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'men': {'positive': 8, 'negative': 0, 'ratio': inf},
#  'mask': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'xavier': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'forneret': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jennif': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '50.000': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'coin': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'trish': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wakeup': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'besid': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'dirti': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'lmaooo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '😤': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'inspir': {'positive': 6, 'negative': 0, 'ratio': inf},
#  'twoof': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'gr8': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wkend': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'cheltenham': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'kale': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'crisp': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'x37': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'worldwid': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'sfvbeta': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'vantast': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'xcylin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bundl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'realisticli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'nelson': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mandela': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'recent': {'positive': 8, 'negative': 0, 'ratio': inf},
#  'chenab': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'flow': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'incredibleindia': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'salmon': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'super-blend': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'youth@bipolaruk.org.uk': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'alma': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mater': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'highschoolday': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'clientvisit': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'christian': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'lizaminnelli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'upcom': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'natur': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pefumeri': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'neal': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yard': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'covent': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fback': {'positive': 26, 'negative': 0, 'ratio': inf},
#  'indo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'harmo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'americano': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'handshom': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'juga': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hurray': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'exec': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'loryn.good@lincs-chamber.co.uk': {'positive': 1,
#   'negative': 0,
#   'ratio': inf},
#  'china': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'homosexu': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hyungbot': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'timetunnel': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '1982': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hiii': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'ili': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'domino': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hastili': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pakistani': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'x36': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '3point': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dreamteam': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bailey': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'pbb': {'positive': 4, 'negative': 0, 'ratio': inf},
#  '737gold': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'drank': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wale': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'yippe': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '💟': {'positive': 2, 'negative': 0, 'ratio': inf},
#  "u'r": {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bigot': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'squat': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dobar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'musicolog': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'iflix': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bisexu': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'minal': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'aidzin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'smu': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'oval': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'basketbal': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'whahahaha': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'soamaz': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'a5': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'teamr': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'greatli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cinepambata': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mechan': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'form': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'sali': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'swisher': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ducktail': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'surreal': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'exposur': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sotw': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jingli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jangli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'loveli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'halesowen': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'blackcountryfair': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'assess': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ooz': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'amassiveoverdoseofship': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'chan': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gemma': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'orlean': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'geskenya': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'obamainkenya': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'magicalkenya': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'greatkenya': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'allgoodthingsk': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'umaru': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'singer': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'label': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'batch': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'princip': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wooftast': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'necessari': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'whatev': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'abstin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'relentlessli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'approxim': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'oldschool': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'runescap': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'daaay': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jumma_mubarik': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'frnd': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'stay_bless': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pussycat': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pretoria': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fahrinahmad': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tengkuaaronshah': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'eksperimencinta': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tykkäsin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'videosta': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '200sub': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '15e': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'paysafecard': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'lue': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hoodi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'eeep': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sohappyrightnow': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mmm': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'azz-set': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gain': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'valu': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'manthan': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tune': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'maxfreshmov': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'loneliest': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tattoo': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'friday.and': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'magnific': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'rashmi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dedic': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'happyfriday': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'rad': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fanart': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fennel': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'journal': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'land': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'yesss': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'gomez': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tomlinson': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'payn': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'caradelevingn': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '🌷': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'iamca': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'afti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'goodmorn': {'positive': 7, 'negative': 0, 'ratio': inf},
#  'prokabaddi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'koel': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mallick': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'recit': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'anthem': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yournaturallead': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'youngnaturallead': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mon': {'positive': 3, 'negative': 0, 'ratio': inf},
#  '27juli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cumbria': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'flockstar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'thur': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '30juli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'itv': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sleeptight': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'haveagoodday': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fulli': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'intend': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '>:d': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'teamadmicro': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fridaydownpour': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'rohit': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sheer': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'obama': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'innumer': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'presid': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'shauri': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yako': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'memotohat': {'positive': 1, 'negative': 0, 'ratio': inf},
#  "t'wa": {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cabincrew': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'langkawi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fulfil': {'positive': 4, 'negative': 0, 'ratio': inf},
#  '👉': {'positive': 4, 'negative': 0, 'ratio': inf},
#  '👈': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'ex-tweleb': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'makeov': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'brilliantli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'happyyi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'birthdaaayyy': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'program': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'career': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'overwhelmingli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'aha': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'beaut': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '♬': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'deo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'faaabul': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'aluminiumfre': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'stayfresh': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'john': {'positive': 6, 'negative': 0, 'ratio': inf},
#  'navig': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'thnk': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'progrmr': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '9am': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'poetri': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'frequentfly': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'londondairi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  ":')": {'positive': 2, 'negative': 0, 'ratio': inf},
#  'chuckl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'doh': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'subscrib': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'stamina': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tweeti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '-->': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'introduc': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'spread': {'positive': 7, 'negative': 0, 'ratio': inf},
#  'supa': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dupa': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dartmoor': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dii': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'smf': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ft': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'stationari': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'specialis': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'thermal': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'survey': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'south': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'scamper': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'chweina': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jotzh': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'coat': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'beforehand': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'foh': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'menac': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'admin': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'lukri': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'redid': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'v.ball': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'atm': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'suitcas': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'hang-copi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  "dostoevsky'": {'positive': 1, 'negative': 0, 'ratio': inf},
#  'voucher': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bugatti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'مطعم_هاشم': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'a7la': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bdayt': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mnwreeen': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jazz': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'x34': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pbevent': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hq': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yoona': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hairpin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mastership': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'paindo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'await': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'manni': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'brijresid': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '156': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'encompass': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bhk': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '91': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '975-580-': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '444': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'honor': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'curri': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'milano': {'positive': 1, 'negative': 0, 'ratio': inf},
#  ':-d': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'gass': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'starsquad': {'positive': 3, 'negative': 0, 'ratio': inf},
#  '⭐': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'utc': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'flume': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'kaytranada': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'alunageorg': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'certainti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'solv': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '👊': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'totem': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'alic': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'checkout': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'goodwynsgoodi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fade': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'moan': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jozi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tix': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'atl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yellow': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'atla': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yein': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'selo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'waiter': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'titl': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'wrip': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'conni': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'crew': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'sweetan': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'soprano': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ukrain': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'x33': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'olli': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'disney.art': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'elmoprinssi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'salsa': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'blogiversari': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bohol': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'briliant': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'annual': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '\U000fe334': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yeheyi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pinya': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'whoooah': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tranc': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'subject': {'positive': 6, 'negative': 0, 'ratio': inf},
#  'jungl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'accommod': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sandroforceo': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'ceo': {'positive': 8, 'negative': 0, 'ratio': inf},
#  '1month': {'positive': 8, 'negative': 0, 'ratio': inf},
#  'workinprogress': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'finnigan': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'loyal': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'fotoset': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'reus': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'muntu': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gem': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'falco': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'supersmash': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hotnsexi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'friskyfriday': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tissu': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hotb': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'classicassur': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'thrill': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'aerial': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'camera': {'positive': 6, 'negative': 0, 'ratio': inf},
#  'oper': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'boom': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ferri': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'central': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'after-work': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'resto': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'drinkt': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'koffi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'a6': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'stargat': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'atlanti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'muaahhh': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '🙈': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'nagsend': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ulit': {'positive': 3, 'negative': 0, 'ratio': inf},
#  '🎈': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'legget': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'qui': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'per': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'encourag': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'employ': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'poster': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'sticker': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tablet': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'milo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'aurini': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'juicebro': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pillar': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'boii': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'smashingbook': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bibl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'lamo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fangirl': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'platon': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'resid': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'servicewithasmil': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bloodlin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'huski': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'obituari': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'goofingaround': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dah': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'bitter': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'anger': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hatr': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'indiffer': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'zach': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ac': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'excel': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'boggl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fatigu': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'baareeq': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gamedev': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hobbi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tweenie_fox': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'accessori': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tamang': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hinala': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'niam': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'selfiee': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'lass': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ale': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'feminist': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fought': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'snobbi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mighti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '🔥': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'jog': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'remot': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'newli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ebay': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'disneyinfin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'starwar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'charact': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'preorder': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'starter': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'homi': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'skin': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'chant': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'heeeyyy': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'woah': {'positive': 3, 'negative': 0, 'ratio': inf},
#  '★': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'phew': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'philippin': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '😀': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '😃': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '😅': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tombraid': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hype': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'thejuiceinthemix': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'rela': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'prioriti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'collaps': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'chaotic': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cosa': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '<---': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'alliter': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'oppayaa': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'natgeo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'stoke': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'approv': {'positive': 3, 'negative': 0, 'ratio': inf},
#  "god'": {'positive': 2, 'negative': 0, 'ratio': inf},
#  'jisung': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'nicola': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'brighten': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'helen': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'brian': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'creak': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'abuti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tweetland': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'xma': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'skyblock': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bcaus': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'unniee': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'nuka': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'penacova': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'djset': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'kizomba': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'latinhous': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'housemus': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'portug': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tast': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'yer': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'mtn': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mistress': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'saphir': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '4000': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'coconut': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sambal': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mussel': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'recip': {'positive': 6, 'negative': 0, 'ratio': inf},
#  'kalin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mixcloud': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sarcasm': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hehe': {'positive': 8, 'negative': 0, 'ratio': inf},
#  'benson': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'solid': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '16/17': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '°': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '😜': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'maryhick': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'musicbiz': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sheskindahot': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fleekil': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mbalula': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'africa': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mexican': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'scar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'donut': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'foiegra': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'stark': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'incred': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'poem': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dale': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jcreport': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'piggin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'botan': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'soap': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'freshli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '3week': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'heal': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tobi-bro': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'isp': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cam': {'positive': 3, 'negative': 0, 'ratio': inf},
#  "masha'allah": {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wwat': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'franc': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'yaaay': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'beirut': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'soda': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fuller': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '💓': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'rettweet': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'mvg': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'valuabl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bergerac': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'u21': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'individu': {'positive': 2, 'negative': 0, 'ratio': inf},
#  "beach'": {'positive': 1, 'negative': 0, 'ratio': inf},
#  'suicid': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'squad': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fond': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'christoph': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'cocki': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'prove': {'positive': 3, 'negative': 0, 'ratio': inf},
#  "attitude'": {'positive': 1, 'negative': 0, 'ratio': inf},
#  'improv': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'suggest': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'inde': {'positive': 6, 'negative': 0, 'ratio': inf},
#  'intellig': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'home-bas': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fleur': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'readystock_hijabmart': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'idr': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '325.000': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '200.000': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tompolo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'aim': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'buyer': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'particularli': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'mam': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'feytyaz': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'stiffen': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ricky_feb': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'grindea': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'courier': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'crypt': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'arma': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'limbo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'orchard': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'karachi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'accumul': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'maroon': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cocktail': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'mididress': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '0-100': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '1100d': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'auto-focu': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'vein': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'glaze': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pake': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'joim': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'troop': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mail': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'ladolcevitainluxembourg@hotmail.com': {'positive': 1,
#   'negative': 0,
#   'ratio': inf},
#  'prrequest': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'journorequest': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'the_madstork': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'shaun': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'actress': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wick': {'positive': 8, 'negative': 0, 'ratio': inf},
#  'hola': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'houston': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tx': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'jenni': {'positive': 1, 'negative': 0, 'ratio': inf},
#  "year'": {'positive': 2, 'negative': 0, 'ratio': inf},
#  'stumbl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'prob.nic': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'choker': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'seouljin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'photoset': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'sadomasochistsparadis': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wynter': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'outtak': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sadomasochist': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'paradis': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cypher': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'amen': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'x32': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'corner': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'addict': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'owe': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ape': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'saar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'vers': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'butterfli': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bonu': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'yummmyyi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dosa': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'achi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'bawi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'queenesth': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sharp': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'poldi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cimbom': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bruhhh': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'knowledg': {'positive': 2, 'negative': 0, 'ratio': inf},
#  '1tb': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'depart': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'anz': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'offshor': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gottolovebank': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'in-shaa-allah': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dua': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'aameen': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '4/5': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'coca': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cola': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fanta': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'pepsi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sprite': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'all': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sweeeti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  ';-)': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'welcometweet': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'setup': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'carpet': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'judgment': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hypocrit': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'narcissist': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jumpsuit': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'verg': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'owl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'constant': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sia': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'religion': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bencher': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'porsch': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'paddock': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'budapestgp': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'johnyherbert': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'porschesupercup': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'koyal': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'melodi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wirh': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'arc': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'x31': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'wolv': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'desir': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ameen': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'kca': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'votejkt': {'positive': 1, 'negative': 0, 'ratio': inf},
#  '48id': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'helpinggroupdm': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dp': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'chick': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'guid': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'zonzofox': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'bhaiya': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'patti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'elabor': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'merdeka': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'palac': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'plusmil': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'servic': {'positive': 5, 'negative': 0, 'ratio': inf},
#  'hahahaa': {'positive': 1, 'negative': 0, 'ratio': inf},
#  ...}

# %% [markdown]
# Notice the difference between the positive and negative ratios. Emojis like :( and words like 'me' tend to have a negative connotation. Other words like glad, community, arrives, tend to be found in the positive tweets.

# %%
# Test your function
w2_unittest.test_get_words_by_threshold(get_words_by_threshold, freqs)
# Out:
# Wrong number of elements in output dictionary.
# 	Expected: 24.
# 	Got: 3537.
# Wrong output values.
# 	Expected: {'followfriday': {'ratio': 24.0}}.
# 	Got: {'followfriday': inf}.
# Wrong output values.
# 	Expected: {'flipkartfashionfriday': {'ratio': 17.0}}.
# 	Got: {'flipkartfashionfriday': inf}.
# Wrong output values.
# 	Expected: {':D': {'ratio': 524.0}}.
# 	Got: {':D': inf}.
# Wrong output values.
# 	Expected: {':p': {'ratio': 105.0}}.
# 	Got: {':p': inf}.
# Wrong output values.
# 	Expected: {'influenc': {'ratio': 17.0}}.
# 	Got: {'influenc': inf}.
# Wrong output values.
# 	Expected: {':-)': {'ratio': 553.0}}.
# 	Got: {':-)': inf}.
# Wrong output values.
# 	Expected: {"here'": {'ratio': 21.0}}.
# 	Got: {"here'": inf}.
# Wrong output values.
# 	Expected: {'youth': {'ratio': 15.0}}.
# 	Got: {'youth': inf}.
# Wrong output values.
# 	Expected: {'bam': {'ratio': 45.0}}.
# 	Got: {'bam': inf}.
# Wrong output values.
# 	Expected: {'warsaw': {'ratio': 45.0}}.
# 	Got: {'warsaw': inf}.
# Wrong output values.
# 	Expected: {'shout': {'ratio': 12.0}}.
# 	Got: {'shout': inf}.
# Wrong output values.
# 	Expected: {';)': {'ratio': 23.0}}.
# 	Got: {';)': inf}.
# Wrong output values.
# 	Expected: {'stat': {'ratio': 52.0}}.
# 	Got: {'stat': inf}.
# Wrong output values.
# 	Expected: {'blog': {'ratio': 28.0}}.
# 	Got: {'blog': inf}.
# Wrong output values.
# 	Expected: {'fav': {'ratio': 12.0}}.
# 	Got: {'fav': inf}.
# Wrong output values.
# 	Expected: {'fantast': {'ratio': 10.0}}.
# 	Got: {'fantast': inf}.
# Wrong output values.
# 	Expected: {'fback': {'ratio': 27.0}}.
# 	Got: {'fback': inf}.
# Wrong output values.
# 	Expected: {'pleasur': {'ratio': 11.0}}.
# 	Got: {'pleasur': inf}.
# Wrong output values.
# 	Expected: {'←': {'ratio': 10.0}}.
# 	Got: {'←': inf}.
# Wrong output values.
# 	Expected: {'aqui': {'ratio': 10.0}}.
# 	Got: {'aqui': inf}.
# Wrong number of elements in output dictionary.
# 	Expected: 7.
# 	Got: 3534.
# Wrong output values.
# 	Expected: {':D': {'ratio': 524.0}}.
# 	Got: {':D': inf}.
# Wrong output values.
# 	Expected: {':p': {'ratio': 105.0}}.
# 	Got: {':p': inf}.
# Wrong output values.
# 	Expected: {':-)': {'ratio': 553.0}}.
# 	Got: {':-)': inf}.
# Wrong output values.
# 	Expected: {'bam': {'ratio': 45.0}}.
# 	Got: {'bam': inf}.
# Wrong output values.
# 	Expected: {'warsaw': {'ratio': 45.0}}.
# 	Got: {'warsaw': inf}.
# Wrong output values.
# 	Expected: {'stat': {'ratio': 52.0}}.
# 	Got: {'stat': inf}.
#  124  Tests passed
#  28  Tests failed

# %% [markdown]
# <a name='5'></a>
# ## 5 - Error Analysis
#
# In this part you will see some tweets that your model missclassified. Why do you think the missclassifications happened? Were there any assumptions made by your naive bayes model?

# %%
# Some error analysis done for you
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b'truli later move know queen bee upward bound movingonup'
# 1	0.00	b'new report talk burn calori cold work harder warm feel better weather :p'
# 1	0.00	b'harri niall 94 harri born ik stupid wanna chang :D'
# 1	0.00	b'park get sunlight'
# 1	0.00	b'uff itna miss karhi thi ap :p'
# 0	1.00	b'hello info possibl interest jonatha close join beti :( great'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'pat jay'
# 0	1.00	b'sr financi analyst expedia inc bellevu wa financ expediajob job job hire'

# %% [markdown]
# <a name='6'></a>
# ## 6 - Predict with your own Tweet
#
# In this part you can predict the sentiment of your own tweet.

# %%
# Test with your own tweet - feel free to modify `my_tweet`
my_tweet = 'I am happy because I am learning :)'

p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 9.571143871339594

# %% [markdown]
# Congratulations on completing this assignment. See you next week!
